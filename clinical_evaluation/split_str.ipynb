# %%
import os 
import numpy as np
import pandas as pd
import json
from evaluate_predictions import PredictionEvaluator

# %%
from utils import *

# %%
# 'trước khí quản, dưới quai động mạch chủ, dưới carina và rốn phổi phải' --> 'trước khí quản', 'dưới quai động mạch chủ', 'rốn phổi phải'
# 'trước khí quản, dưới carina, dưới hạch vú trái' --> 'trước khí quản', 'dưới carina', 'dưới hạch vú trái'

# # But: 
# 'trung thất (trước khí quản, cửa và dưới carina)' --> 'trung thất (trước khí quản', 'cửa và dưới carina)'
# 'trung thất trước khí quản, trước và dưới carina' --> 'trung thất trước khí quản', 'trước và dưới carina',
# 'sau hầu trái, dọc trong và sau cơ ức đòn chũm trái (nhóm iib, iii, iv, va, vb), thượng đòn trái' --> 'sau hầu trái', 'dọc trong và sau cơ ức đòn chũm trái (nhóm iib, iii, iv, va, vb)', 'thượng đòn trái'
#  'trước khí quản và bên trái khí quản đoạn thấp, dưới carina thuộc nhóm 4r, 4l, 7', -->  'trước khí quản','bên trái khí quản đoạn thấp' , 'dưới carina thuộc nhóm 4r, 4l, 7'

# %%
# --> load json --> lowercase --> remove "ở" trước --> tách chuỗi xu_ly_chuoi_vi_tri_nang_cao with special list --> remove single word --> duplicate

# %%
# --> load json --> lowercase

# %%
from utils import * 

# directory_paths = ['/home/jovyan/shared/tienhuu060102/data-petct/clinical_eval/datajson/adaptive_cosmos_lmed', 
# '/home/jovyan/shared/tienhuu060102/data-petct/clinical_eval/datajson/adaptive_cosmos_Lmed_O_P_ver2', '/home/jovyan/shared/tienhuu060102/data-petct/clinical_eval/datajson/adaptive_cosmos_m3d', '/home/jovyan/shared/tienhuu060102/data-petct/clinical_eval/datajson/adaptive_cosmos_m3d_LORA_O_P_ver2', '/home/jovyan/shared/tienhuu060102/data-petct/clinical_eval/datajson/ctvit_Lmed_LORA_O_P_ver2', '/home/jovyan/shared/tienhuu060102/data-petct/clinical_eval/datajson/ctvit_m3d_O_P_ver2', '/home/jovyan/shared/tienhuu060102/data-petct/clinical_eval/datajson/noise_ctvit_m3d_projector', '/home/jovyan/shared/tienhuu060102/data-petct/clinical_eval/datajson/noise_ctvit_med', '/home/jovyan/shared/tienhuu060102/data-petct/clinical_eval/datajson/ctvit_Lmed_O_P_C', '/home/jovyan/shared/tienhuu060102/data-petct/clinical_eval/datajson/ctvit_m3d_O_P_C', '/home/jovyan/shared/tienhuu060102/data-petct/clinical_eval/datajson/adaptive_cosmos_lmed_O_P_C_revise','/home/jovyan/shared/tienhuu060102/data-petct/clinical_eval/datajson/adaptive_cosmos_m3d_O_P_C' ]
directory_paths = ['GPT_new']

print( "length of predictiosn configs: ",   len(directory_paths))

special_path = './vitri_dacbiet.txt'
special_list = read_set_from_file(special_path)



target_key = 'Vị trí của khối u, tổn thương, bất thường'
vitri_texts = set()
for directory_path in directory_paths: 
    vitri_texts.update( extract_unique_values_from_json_files(directory_path, target_key))

gt_path = '/home/jovyan/shared/tienhuu060102/data-petct/clinical_eval/datajson/data'
vitri_texts_gt = extract_unique_values_from_json_files(gt_path, target_key)



splitted_unique_values = []
for text in vitri_texts: 
    text = remove_x_at_start(text, 'ở')
    texts = xu_ly_chuoi_vi_tri_nang_cao(text, special_list)
    splitted_unique_values.extend(texts)
    
splitted_unique_values = remove_and_report_single_word_strings(set(splitted_unique_values))

splitted_unique_values_gt = []
for text in vitri_texts_gt: 
    text = remove_x_at_start(text, 'ở')
    texts = xu_ly_chuoi_vi_tri_nang_cao(text, special_list)
    splitted_unique_values_gt.extend(texts)
    
splitted_unique_values_gt = remove_and_report_single_word_strings(set(splitted_unique_values_gt))


write_set_to_file(splitted_unique_values, 'vitri_prediction_GPT.txt')
# write_set_to_file(splitted_unique_values_gt, 'vitri_gt.txt')

print(len(splitted_unique_values), len(splitted_unique_values_gt))
# Out:
# length of predictiosn configs:  1
# Successfully read 14 unique elements from './vitri_dacbiet.txt'
# --- No single-word strings found to remove ---
# --- Removed single-word strings ---
# - '3)'
# - '4l'
# - '7'
# - 'iii'
# - 'iv'
# - 'thấp'
# - 'va'
# - 'vb)'
# ---------------------------------
# Successfully wrote 11 items to 'vitri_prediction_GPT.txt'
# 11 160

# %%
splitted_unique_values
# Out:
# {'dưới carina',
#  'góc hàm',
#  'hố bẹn hai bên',
#  'hố nách hai bên',
#  'phía trong cơ ức đòn chũm (nhóm iib) hai bên',
#  'thùy giữa phổi phải',
#  'thùy trái tuyến giáp',
#  'thùy trên phổi trái',
#  'thận trái',
#  'trung thất ở trước khí quản',
#  'trực tràng'}

# %%
vitri_texts_gt
# Out:
# {' hạch chân hoành phải ',
#  ' màng phổi trung thất  và khoang màng phổi trái',
#  ' ở cạnh phải khí quản, cạnh quai động mạch chủ, cửa sổ chủ phổi, dưới carina và hạch rốn phổi phải',
#  'bên phải khí quản đoạn cao',
#  'bên trái',
#  'cung sau xương sườn 4 bên trái; xương cánh chậu; trần ổ cối bên trái',
#  'cạnh bên phải khí quản đoạn thấp và trước carina',
#  'cạnh khí quản đoạn thấp và dưới carina',
#  'cạnh khí quản đoạn thấp và phế quản gốc hai bên',
#  'cạnh phải khí quản đoạn cao, hạch rốn phổi phải',
#  'cạnh phải khí quản đoạn thấp',
#  'cạnh phải khí quản đoạn thấp, cửa sổ chủ phổi',
#  'cạnh phải khí quản đoạn thấp, dưới carina và hạch rốn phổi phải',
#  'cạnh phải khí quản đoạn thấp, dưới carina, hạch rốn phổi hai bên',
#  'cạnh phải khí quản đoạn thấp, hạch rốn phổi phải',
#  'cạnh phải khí quản đoạn thấp, trước và dưới carina, hạch rốn phổi phải',
#  'cạnh phải khí quản, trước và dưới carina, hạch rốn phổi phải',
# ...

# %%
vitri_texts
# Out:
# {'1/3 dưới rốn phổi phải',
#  '1/3 giữa thực quản',
#  '1/3 trên thực quản',
#  '1/3 trên thực quản, ngang mức đốt sống d9',
#  '1/3 trên đoạn trên thực quản',
#  'bên phải',
#  'bên phải khí quản đoạn thấp, trước quai động mạch chủ',
#  'bên trái',
#  'cạnh bên phải khí quản đoạn cao',
#  'cạnh bên phải khí quản đoạn cao, cạnh thực quản đoạn 1/3 trên',
#  'cạnh bên phải khí quản đoạn cao, cạnh động mạch chủ và trước carina',
#  'cạnh bên phải khí quản đoạn cao, dưới carina',
#  'cạnh bên phải khí quản đoạn thấp, trước mạch máu',
#  'cạnh bên phải khí quản đoạn thấp, trước và dưới carina, hạch rốn phổi hai bên',
#  'cạnh bên phải thực quản đoạn cao',
#  'cạnh hai bên khí quản đoạn thấp, cửa sổ phế chủ, trước và dưới carina, hạch rốn phổi hai bên',
#  'cạnh hai bên khí quản đoạn thấp, trước mạch máu, trước và dưới quai động mạch chủ',
#  'cạnh hai bên khí quản, trước và dưới carina',
#  'cạnh khí quản đoạn cao',
# ...

# %%
from typing import List, Any, Set

def remove_and_report_single_word_strings_from_list(input_list: List[Any]) -> List[Any]:
    """
    Loại bỏ các chuỗi chỉ có một từ khỏi một danh sách (list) và in ra các chuỗi đã bị loại bỏ.

    Hàm này duyệt qua danh sách đầu vào, xác định các chuỗi chỉ chứa đúng một từ
    (sau khi loại bỏ khoảng trắng thừa ở đầu/cuối và tách bằng khoảng trắng).
    Các chuỗi một từ *duy nhất* đã bị loại bỏ sẽ được thu thập và in ra.
    Hàm trả về một danh sách mới chứa các mục từ danh sách đầu vào
    (bao gồm cả các mục không phải chuỗi) mà KHÔNG PHẢI là chuỗi một từ,
    duy trì thứ tự tương đối ban đầu của các mục được giữ lại.

    Args:
        input_list: Một danh sách (list) các mục đầu vào. Hàm sẽ chủ yếu xử lý
                    các mục là chuỗi, các mục khác sẽ được giữ lại.

    Returns:
        Một danh sách (list) mới chứa các mục từ danh sách đầu vào
        mà KHÔNG PHẢI là chuỗi một từ. Thứ tự của các mục được giữ lại
        sẽ tương ứng với thứ tự trong danh sách đầu vào.
    """
    # Input validation (optional but good practice)
    if not isinstance(input_list, list):
        print("Warning: Input is not a list. Attempting to convert and process.")
        try:
            # Try converting common iterables to a list
            input_list = list(input_list)
        except TypeError:
            raise TypeError("Input must be a list or convertible to a list.")

    # Use a set to efficiently track unique strings removed for reporting
    unique_strings_removed: Set[str] = set()
    # Use a list to store items we want to keep, preserving order
    items_to_keep: List[Any] = []

    for item in input_list:
        # Process only if the item is a string
        if isinstance(item, str):
            # item.split() handles leading/trailing/multiple spaces automatically
            words = item.split()
            if len(words) == 1:
                # It's a single-word string, mark it for removal reporting
                unique_strings_removed.add(item)
                # Do NOT add it to items_to_keep
            else:
                # It's not a single-word string (0 words or >1 word), keep it
                items_to_keep.append(item)
        else:
            # If the item is not a string, keep it as is
            items_to_keep.append(item)

    # ----- Report the unique strings that were removed -----
    if unique_strings_removed:
        print("\n--- Removed single-word strings (unique occurrences) ---")
        # Sort the set before printing for consistent output order
        for removed_str in sorted(list(unique_strings_removed)):
            print(f"- '{removed_str}'")
        print("--------------------------------------------------------")
    else:
        print("\n--- No single-word strings found to remove ---")

    return items_to_keep
# Out:
# Original List:
# ['xin chào', 'tạm biệt', 'phở', 'ngon', '   nước  mắm ', 'Việt Nam', 123, 'bún', '', '  ', 'phở', None, 'lập trình viên']
#
# --- Removed single-word strings (unique occurrences) ---
# - 'bún'
# - 'ngon'
# - 'phở'
# --------------------------------------------------------
#
# Filtered List (items kept):
# ['xin chào', 'tạm biệt', '   nước  mắm ', 'Việt Nam', 123, '', '  ', None, 'lập trình viên']
#
# --- Processing a tuple ---
# ...
#
# --- Removed single-word strings (unique occurrences) ---
# - 'bốn'
# - 'một'
# --------------------------------------------------------
#
# Filtered List (from tuple):
# ['hai ba', 5]

# %%
from utils import * 

def process_vitri(text):
        text = text.lower()
        text = remove_x_at_start(text, 'ở')
        texts = xu_ly_chuoi_vi_tri_nang_cao(text, special_list)
        texts = remove_and_report_single_word_strings_from_list(texts)
        return texts 
target_key = 'Vị trí của khối u, tổn thương, bất thường'
ex =  load_json('/home/jovyan/shared/tienhuu060102/data-petct/clinical_eval/datajson/adaptive_cosmos_lmed/6ab1fc3c7dcf1bf0a33f26d16205f3111a0f53be1621987d5659b99b53fb772e.json')

# %%
ex
# Out:
# [{'Kích thước khối u, tổn thương, bất thường': '26 x 18 mm',
#   'Hình dạng của khối u, tổn thương, bất thường': 'Hình ảnh hạch',
#   'Vị trí của khối u, tổn thương, bất thường': 'Trước khí quản, trước và dưới carina, dưới quai động mạch chủ',
#   'Mức độ FDG': {'SUVmax': '10.7', 'Tăng chuyển hoá FDG': 'Có tăng'},
#   'Xâm lấn': 'Không có',
#   'Giai đoạn chuyển hoá': 'Không có'},
#  {'Kích thước khối u, tổn thương, bất thường': '10 mm',
#   'Hình dạng của khối u, tổn thương, bất thường': 'Hình ảnh hạch',
#   'Vị trí của khối u, tổn thương, bất thường': 'Hố nách hai bên',
#   'Mức độ FDG': {'SUVmax': 'Không có', 'Tăng chuyển hoá FDG': 'Không có'},
#   'Xâm lấn': 'Không có',
#   'Giai đoạn chuyển hoá': 'Không có'}]

# %%
special_path = './vitri_dacbiet.txt'
special_list = read_set_from_file(special_path)
# Out:
# Successfully read 11 unique elements from './vitri_dacbiet.txt'

# %%
for obj in ex : 
    obj[target_key] = process_vitri(obj[target_key])
# Out:
# --- No single-word strings found to remove ---
#
# --- No single-word strings found to remove ---

# %%
ex = expand_dictionaries_by_list_key(ex)
ex
# Out:
# [{'Kích thước khối u, tổn thương, bất thường': '26 x 18 mm',
#   'Hình dạng của khối u, tổn thương, bất thường': 'Hình ảnh hạch',
#   'Vị trí của khối u, tổn thương, bất thường': 'trước khí quản',
#   'Mức độ FDG': {'SUVmax': '10.7', 'Tăng chuyển hoá FDG': 'Có tăng'},
#   'Xâm lấn': 'Không có',
#   'Giai đoạn chuyển hoá': 'Không có'},
#  {'Kích thước khối u, tổn thương, bất thường': '26 x 18 mm',
#   'Hình dạng của khối u, tổn thương, bất thường': 'Hình ảnh hạch',
#   'Vị trí của khối u, tổn thương, bất thường': 'trước và dưới carina',
#   'Mức độ FDG': {'SUVmax': '10.7', 'Tăng chuyển hoá FDG': 'Có tăng'},
#   'Xâm lấn': 'Không có',
#   'Giai đoạn chuyển hoá': 'Không có'},
#  {'Kích thước khối u, tổn thương, bất thường': '26 x 18 mm',
#   'Hình dạng của khối u, tổn thương, bất thường': 'Hình ảnh hạch',
#   'Vị trí của khối u, tổn thương, bất thường': 'dưới quai động mạch chủ',
#   'Mức độ FDG': {'SUVmax': '10.7', 'Tăng chuyển hoá FDG': 'Có tăng'},
#   'Xâm lấn': 'Không có',
# ...

# %%
input : 
[{'Kích thước khối u, tổn thương, bất thường': '26 x 18 mm',
  'Hình dạng của khối u, tổn thương, bất thường': 'Hình ảnh hạch',
  'Vị trí của khối u, tổn thương, bất thường': ['trước khí quản',
   'trước và dưới carina',
   'dưới quai động mạch chủ'],
  'Mức độ FDG': {'SUVmax': '10.7', 'Tăng chuyển hoá FDG': 'Có tăng'},
  'Xâm lấn': 'Không có',
  'Giai đoạn chuyển hoá': 'Không có'},
 {'Kích thước khối u, tổn thương, bất thường': '10 mm',
  'Hình dạng của khối u, tổn thương, bất thường': 'Hình ảnh hạch',
  'Vị trí của khối u, tổn thương, bất thường': ['hố nách hai bên'],
  'Mức độ FDG': {'SUVmax': 'Không có', 'Tăng chuyển hoá FDG': 'Không có'},
  'Xâm lấn': 'Không có',
  'Giai đoạn chuyển hoá': 'Không có'}]


output : 
[{'Kích thước khối u, tổn thương, bất thường': '26 x 18 mm',
  'Hình dạng của khối u, tổn thương, bất thường': 'Hình ảnh hạch',
  'Vị trí của khối u, tổn thương, bất thường': 'trước khí quản',
  'Mức độ FDG': {'SUVmax': '10.7', 'Tăng chuyển hoá FDG': 'Có tăng'},
  'Xâm lấn': 'Không có',
  'Giai đoạn chuyển hoá': 'Không có'},
  {'Kích thước khối u, tổn thương, bất thường': '26 x 18 mm',
  'Hình dạng của khối u, tổn thương, bất thường': 'Hình ảnh hạch',
  'Vị trí của khối u, tổn thương, bất thường': 'trước và dưới carina',
  'Mức độ FDG': {'SUVmax': '10.7', 'Tăng chuyển hoá FDG': 'Có tăng'},
  'Xâm lấn': 'Không có',
  'Giai đoạn chuyển hoá': 'Không có'},
  {'Kích thước khối u, tổn thương, bất thường': '26 x 18 mm',
  'Hình dạng của khối u, tổn thương, bất thường': 'Hình ảnh hạch',
  'Vị trí của khối u, tổn thương, bất thường': 'dưới quai động mạch chủ',
  'Mức độ FDG': {'SUVmax': '10.7', 'Tăng chuyển hoá FDG': 'Có tăng'},
  'Xâm lấn': 'Không có',
  'Giai đoạn chuyển hoá': 'Không có'},
 {'Kích thước khối u, tổn thương, bất thường': '10 mm',
  'Hình dạng của khối u, tổn thương, bất thường': 'Hình ảnh hạch',
  'Vị trí của khối u, tổn thương, bất thường': 'hố nách hai bên',
  'Mức độ FDG': {'SUVmax': 'Không có', 'Tăng chuyển hoá FDG': 'Không có'},
  'Xâm lấn': 'Không có',
  'Giai đoạn chuyển hoá': 'Không có'}]
# Out:
#   Cell In[8], line 1
#     input :
#             ^
# SyntaxError: invalid syntax

# %%
import copy # Import copy module for creating copies of dictionaries
from typing import List, Dict, Any, Union

def expand_dictionaries_by_list_key(
    data_list: List[Dict[str, Any]],
    target_key: str = 'Vị trí của khối u, tổn thương, bất thường'
) -> List[Dict[str, Any]]:
    """
    Expands dictionaries in a list based on a target key holding a list value.

    If a dictionary in the input list has the `target_key` and its value
    is a list, this function creates a separate dictionary for each element
    in that list. Each new dictionary is a copy of the original, but the
    value for the `target_key` is replaced with the single element from the list.

    Dictionaries where the `target_key` does not exist, or its value is not
    a list, are included in the output list unchanged.

    Args:
        data_list: A list of dictionaries to process.
        target_key: The dictionary key whose list value triggers expansion.
                    Defaults to 'Vị trí của khối u, tổn thương, bất thường'.

    Returns:
        A new list of dictionaries, potentially expanded based on the target key.
    """
    output_list: List[Dict[str, Any]] = []

    for item_dict in data_list:
        # Check if the target key exists and its value is a list
        if target_key in item_dict and isinstance(item_dict[target_key], list):
            # Get the list of values for the target key
            list_values = item_dict[target_key]

            # If the list is empty, you might want to decide whether to skip
            # the item entirely or add a version with a default value (e.g., None).
            # Current logic skips items with empty lists for the target key.
            if not list_values:
                 continue # Or handle differently if needed, e.g., output_list.append(item_dict)

            # Iterate through each value in the list
            for single_value in list_values:
                # Create a copy of the original dictionary.
                # Using copy.deepcopy ensures nested structures (like 'Mức độ FDG')
                # are also copied independently, preventing unintended modifications.
                # If nested structures are simple or not modified elsewhere,
                # item_dict.copy() (shallow copy) might suffice. Deepcopy is safer.
                new_dict = copy.deepcopy(item_dict)

                # Replace the list value with the single value in the new dictionary
                new_dict[target_key] = single_value

                # Add the newly created dictionary to the output list
                output_list.append(new_dict)
        else:
            # If the key doesn't exist or the value is not a list,
            # add the original dictionary to the output list as is.
            # Use deepcopy here too if you want to ensure the output list
            # contains independent copies, otherwise just append the reference.
            # For safety and consistency with the expansion case:
            output_list.append(copy.deepcopy(item_dict))
            # Or simply: output_list.append(item_dict) if independence isn't critical

    return output_list

# --- Example Usage ---
input_data = [
    {
        'Kích thước khối u, tổn thương, bất thường': '26 x 18 mm',
        'Hình dạng của khối u, tổn thương, bất thường': 'Hình ảnh hạch',
        'Vị trí của khối u, tổn thương, bất thường': [
            'trước khí quản',
            'trước và dưới carina',
            'dưới quai động mạch chủ'
        ],
        'Mức độ FDG': {'SUVmax': '10.7', 'Tăng chuyển hoá FDG': 'Có tăng'},
        'Xâm lấn': 'Không có',
        'Giai đoạn chuyển hoá': 'Không có'
    },
    {
        'Kích thước khối u, tổn thương, bất thường': '10 mm',
        'Hình dạng của khối u, tổn thương, bất thường': 'Hình ảnh hạch',
        'Vị trí của khối u, tổn thương, bất thường': ['hố nách hai bên'], # List with one item
        'Mức độ FDG': {'SUVmax': 'Không có', 'Tăng chuyển hoá FDG': 'Không có'},
        'Xâm lấn': 'Không có',
        'Giai đoạn chuyển hoá': 'Không có'
    },
    {
        'Kích thước khối u, tổn thương, bất thường': '5 mm',
        'Hình dạng của khối u, tổn thương, bất thường': 'Nốt',
        'Vị trí của khối u, tổn thương, bất thường': 'Phổi phải', # Not a list
        'Mức độ FDG': {'SUVmax': '2.1', 'Tăng chuyển hoá FDG': 'Nghi ngờ'},
        'Xâm lấn': 'Không rõ',
        'Giai đoạn chuyển hoá': 'Không có'
    },
    {
        'Kích thước khối u, tổn thương, bất thường': 'Không xác định',
        'Hình dạng của khối u, tổn thương, bất thường': 'Tổn thương dạng nốt',
        # Missing the target key entirely
        'Mức độ FDG': {'SUVmax': 'Không có', 'Tăng chuyển hoá FDG': 'Không có'},
        'Xâm lấn': 'Không có',
        'Giai đoạn chuyển hoá': 'Không có'
    }
]
# Out:
# [
#   {
#     "Kích thước khối u, tổn thương, bất thường": "26 x 18 mm",
#     "Hình dạng của khối u, tổn thương, bất thường": "Hình ảnh hạch",
#     "Vị trí của khối u, tổn thương, bất thường": "trước khí quản",
#     "Mức độ FDG": {
#       "SUVmax": "10.7",
#       "Tăng chuyển hoá FDG": "Có tăng"
#     },
#     "Xâm lấn": "Không có",
#     "Giai đoạn chuyển hoá": "Không có"
#   },
#   {
#     "Kích thước khối u, tổn thương, bất thường": "26 x 18 mm",
#     "Hình dạng của khối u, tổn thương, bất thường": "Hình ảnh hạch",
#     "Vị trí của khối u, tổn thương, bất thường": "trước và dưới carina",
#     "Mức độ FDG": {
#       "SUVmax": "10.7",
#       "Tăng chuyển hoá FDG": "Có tăng"
#     },
#     "Xâm lấn": "Không có",
#     "Giai đoạn chuyển hoá": "Không có"
#   },
#   {
#     "Kích thước khối u, tổn thương, bất thường": "26 x 18 mm",
#     "Hình dạng của khối u, tổn thương, bất thường": "Hình ảnh hạch",
# ...
